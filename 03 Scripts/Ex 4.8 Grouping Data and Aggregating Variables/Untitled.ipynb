# %% [markdown]
# # Grouping and Aggregating

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\klein\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# 0                  8                     NaN         True         196  ...
# 1                  7                    15.0        False         196  ...
# 2                 12                    21.0        False         196  ...
# 3                  7                    29.0        False         196  ...
# 4                 15                    28.0        False         196  ...
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
# 5             5   3367565        1    prior             6                   2
# 6             6    550135        1    prior             7                   1
# 7             7   3108588        1    prior             8                   1
# 8             8   2295261        1    prior             9                   1
# 9             9   2550362        1    prior            10                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
#
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# ..           ...       ...      ...      ...           ...
# 95          5895   3226575      360    prior             1
# 96          6137   1469869      377    prior             3
# 97          6259   1927023      387    prior             2
# 98          6740    858092      420    prior             4
# 99          6741    119314      420    prior             5
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                    2                  8                     NaN
# 1                    3                  7                    15.0
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
# Exercise 4.8 starts here

# %%
df = ords_prods_merge

# %%
df.head()
# Out:
#    Unnamed: 0.1  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# 0                  8                     NaN         True         196  ...
# 1                  7                    15.0        False         196  ...
# 2                 12                    21.0        False         196  ...
# 3                  7                    29.0        False         196  ...
# 4                 15                    28.0        False         196  ...
#
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head()
# Out:
#    Unnamed: 0.1  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# 0                  8                     NaN         True         196  ...
# 1                  7                    15.0        False         196  ...
# 2                 12                    21.0        False         196  ...
# 3                  7                    29.0        False         196  ...
# 4                 15                    28.0        False         196  ...
#
# ...

# %%
df.head(100)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
# ...

# %%
#apply loyalty labels
df.loc[df['max_order'] > 40, 'loyalty_flags'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flags'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flags'] = 'New customer'
